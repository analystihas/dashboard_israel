# %%
# import IPython
# app = IPython.Application.instance()
# app.kernel.do_shutdown(restart=True)

# %%
import sys
import os

from db_connection import access_db_for_test

client = access_db_for_test()

query = "SELECT * FROM SBOX_ISRAEL.RECEITAS"
result = client.query(query).to_dataframe()

result.dtypes
# Out:
# DATA                 dbdate
# TOTAL_NOTAS           Int64
# NOTAS_REALIZADAS      Int64
# VALOR_TOTAL         float64
# CEPS                 object
# CREATED_AT           dbdate
# dtype: object

# %%
result.sort_values(by="DATA").tail()
# Out:
#           DATA  TOTAL_NOTAS  NOTAS_REALIZADAS  VALOR_TOTAL  \
# 19  2025-11-04           55                54       1233.0
# 16  2025-11-05           41                40        987.0
# 14  2025-11-06           38                36        939.0
# 18  2025-11-07           45                43       1072.5
# 3   2025-11-08           22                20        489.0
#
#                   CEPS  CREATED_AT
# 19  30, 31, 32, 33, 34  2025-11-08
# 16  30, 31, 32, 33, 34  2025-11-08
# 14  30, 31, 32, 33, 34  2025-11-08
# 18  30, 31, 32, 33, 34  2025-11-08
# 3   30, 31, 32, 33, 34  2025-11-08

# %%
result.dtypes
# Out:
# DATA                 dbdate
# TOTAL_NOTAS           Int64
# NOTAS_REALIZADAS      Int64
# VALOR_TOTAL         float64
# CEPS                 object
# CREATED_AT           dbdate
# dtype: object
